# %% [markdown]
# <a href="https://colab.research.google.com/github/NelsonDane/2048-Game-For-CS470/blob/main/collab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content
# !git -C 2048-Game-For-CS470 pull || git clone https://github.com/<repo>.git 2048-Game-For-CS470
# %cd 2048-Game-For-CS470/
# !git pull

# !python main.py
# Out:
# /content
# Already up to date.
# /content/2048-Game-For-CS470
# Already up to date.
#
#  ****** Running generation 0 ******
#
# Population's average fitness: 1603.20000 stdev: 690.52861
# Best fitness: 5000.00000 - size: (4, 64) - species 1 - id 350
# Average adjusted fitness: 0.321
# Mean genetic distance 1.309, standard deviation 0.221
# Population of 500 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    0   500   5000.0    0.321     0
# Total extinctions: 0
# Generation time: 1.345 sec
#
#  ****** Running generation 1 ******
#
# Population's average fitness: 1644.20000 stdev: 696.35218
# Best fitness: 4400.00000 - size: (4, 63) - species 1 - id 586
# Average adjusted fitness: 0.328
# Mean genetic distance 1.368, standard deviation 0.220
# Population of 500 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    1   500   4400.0    0.328     1
# Total extinctions: 0
# Generation time: 1.362 sec (1.353 average)
#
#  ****** Running generation 2 ******
#
# Population's average fitness: 1638.20000 stdev: 729.30156
# Best fitness: 5100.00000 - size: (4, 57) - species 1 - id 1138
# Average adjusted fitness: 0.321
# Mean genetic distance 1.428, standard deviation 0.226
# Population of 500 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    2   500   5100.0    0.321     0
# Total extinctions: 0
# Generation time: 1.358 sec (1.355 average)
#
#  ****** Running generation 3 ******
#
# Population's average fitness: 1700.40000 stdev: 706.20099
# Best fitness: 4400.00000 - size: (4, 63) - species 1 - id 1764
# Average adjusted fitness: 0.386
# Mean genetic distance 1.440, standard deviation 0.221
# Population of 500 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    3   500   4400.0    0.386     1
# Total extinctions: 0
# Generation time: 1.339 sec (1.351 average)
#
#  ****** Running generation 4 ******
#
# Population's average fitness: 1701.20000 stdev: 728.50433
# Best fitness: 5600.00000 - size: (4, 58) - species 1 - id 2344
# Average adjusted fitness: 0.278
# Mean genetic distance 1.439, standard deviation 0.216
# Population of 500 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    4   500   5600.0    0.278     0
# Total extinctions: 0
# Generation time: 1.351 sec (1.351 average)
#
#  ****** Running generation 5 ******
#
# Population's average fitness: 1793.80000 stdev: 760.80323
# Best fitness: 5200.00000 - size: (6, 64) - species 1 - id 2868
# Average adjusted fitness: 0.305
# Mean genetic distance 1.498, standard deviation 0.221
# Population of 500 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    5   500   5200.0    0.305     1
# Total extinctions: 0
# Generation time: 1.378 sec (1.355 average)
#
#  ****** Running generation 6 ******
#
# Population's average fitness: 1710.60000 stdev: 736.38824
# Best fitness: 4500.00000 - size: (4, 54) - species 1 - id 3342
# Average adjusted fitness: 0.366
# Mean genetic distance 1.539, standard deviation 0.237
# Population of 500 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    6   500   4500.0    0.366     2
# Total extinctions: 0
# Generation time: 1.442 sec (1.368 average)
#
#  ****** Running generation 7 ******
#
# Population's average fitness: 1703.60000 stdev: 678.16446
# Best fitness: 4300.00000 - size: (4, 56) - species 1 - id 3963
# Average adjusted fitness: 0.367
# Mean genetic distance 1.615, standard deviation 0.227
# Population of 500 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    7   500   4300.0    0.367     3
# Total extinctions: 0
# Generation time: 2.428 sec (1.500 average)
#
#  ****** Running generation 8 ******
#
# Population's average fitness: 1750.60000 stdev: 742.11835
# Best fitness: 5900.00000 - size: (4, 49) - species 1 - id 4101
# Average adjusted fitness: 0.272
# Mean genetic distance 1.653, standard deviation 0.232
# Population of 500 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    8   500   5900.0    0.272     0
# Total extinctions: 0
# Generation time: 1.643 sec (1.516 average)
#
#  ****** Running generation 9 ******
#
# Population's average fitness: 1681.00000 stdev: 704.91063
# Best fitness: 4500.00000 - size: (5, 58) - species 1 - id 4758
# Average adjusted fitness: 0.374
# Mean genetic distance 1.673, standard deviation 0.238
# Population of 500 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    9   500   4500.0    0.374     1
# Total extinctions: 0
# Generation time: 1.341 sec (1.499 average)
#
#  ****** Running generation 10 ******
#
# Population's average fitness: 1739.00000 stdev: 714.35215
# Best fitness: 4900.00000 - size: (5, 48) - species 1 - id 5398
# Average adjusted fitness: 0.355
# Mean genetic distance 1.700, standard deviation 0.257
# Population of 500 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   10   500   4900.0    0.355     2
# Total extinctions: 0
# Generation time: 1.445 sec (1.509 average)
#
#  ****** Running generation 11 ******
#
# Population's average fitness: 1711.80000 stdev: 757.04740
# Best fitness: 5300.00000 - size: (4, 48) - species 1 - id 5775
# Average adjusted fitness: 0.282
# Mean genetic distance 1.818, standard deviation 0.262
# Population of 500 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   11   500   5300.0    0.282     3
# Total extinctions: 0
# Generation time: 1.340 sec (1.507 average)
#
#  ****** Running generation 12 ******
#
# Population's average fitness: 1754.20000 stdev: 763.54591
# Best fitness: 5300.00000 - size: (4, 42) - species 1 - id 6183
# Average adjusted fitness: 0.276
# Mean genetic distance 1.815, standard deviation 0.255
# Population of 500 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   12   500   5300.0    0.276     4
# Total extinctions: 0
# Generation time: 1.332 sec (1.504 average)
#
#  ****** Running generation 13 ******
#
# Population's average fitness: 1766.00000 stdev: 675.63600
# Best fitness: 4600.00000 - size: (5, 45) - species 1 - id 6660
# Average adjusted fitness: 0.370
# Mean genetic distance 1.738, standard deviation 0.256
# Population of 500 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   13   500   4600.0    0.370     5
# Total extinctions: 0
# Generation time: 1.367 sec (1.507 average)
#
#  ****** Running generation 14 ******
#
# Population's average fitness: 1717.40000 stdev: 728.88767
# Best fitness: 5000.00000 - size: (5, 44) - species 1 - id 7116
# Average adjusted fitness: 0.343
# Mean genetic distance 1.713, standard deviation 0.248
# Population of 500 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   14   500   5000.0    0.343     6
# Total extinctions: 0
# Generation time: 1.333 sec (1.505 average)
#
#  ****** Running generation 15 ******
#
# Population's average fitness: 1735.20000 stdev: 763.51880
# Best fitness: 5700.00000 - size: (4, 45) - species 1 - id 7526
# Average adjusted fitness: 0.279
# Mean genetic distance 1.712, standard deviation 0.232
# Population of 500 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   15   500   5700.0    0.279     7
# Total extinctions: 0
# Generation time: 1.791 sec (1.546 average)
#
#  ****** Running generation 16 ******
#
# Population's average fitness: 1760.20000 stdev: 793.89921
# Best fitness: 5300.00000 - size: (5, 42) - species 1 - id 8321
# Average adjusted fitness: 0.319
# Mean genetic distance 1.759, standard deviation 0.224
# Population of 500 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   16   500   5300.0    0.319     8
# Total extinctions: 0
# Generation time: 2.310 sec (1.633 average)
#
#  ****** Running generation 17 ******
#
# Population's average fitness: 1717.80000 stdev: 708.98742
# Best fitness: 5100.00000 - size: (4, 35) - species 1 - id 8750
# Average adjusted fitness: 0.280
# Mean genetic distance 1.803, standard deviation 0.229
# Population of 500 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   17   500   5100.0    0.280     9
# Total extinctions: 0
# Generation time: 1.324 sec (1.523 average)
#
#  ****** Running generation 18 ******
#
# Population's average fitness: 1712.20000 stdev: 729.76103
# Best fitness: 4900.00000 - size: (4, 28) - species 1 - id 9022
# Average adjusted fitness: 0.349
# Mean genetic distance 1.816, standard deviation 0.218
# Population of 500 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   18   500   4900.0    0.349    10
# Total extinctions: 0
# Generation time: 1.291 sec (1.488 average)
#
#  ****** Running generation 19 ******
#
# Population's average fitness: 1735.40000 stdev: 683.78859
# Best fitness: 4900.00000 - size: (6, 42) - species 1 - id 9634
# Average adjusted fitness: 0.312
# Mean genetic distance 1.866, standard deviation 0.232
# Population of 500 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   19   500   4900.0    0.312    11
# Total extinctions: 0
# Generation time: 1.338 sec (1.487 average)
#
#  ****** Running generation 20 ******
#
# Population's average fitness: 1743.20000 stdev: 736.94895
# Best fitness: 6000.00000 - size: (4, 37) - species 1 - id 10469
# Average adjusted fitness: 0.291
# Mean genetic distance 1.973, standard deviation 0.261
# Population of 500 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   20   500   6000.0    0.291     0
# Total extinctions: 0
# Generation time: 1.319 sec (1.475 average)
#
#  ****** Running generation 21 ******
#
# Population's average fitness: 1683.20000 stdev: 702.33735
# Best fitness: 4900.00000 - size: (5, 38) - species 1 - id 10505
# Average adjusted fitness: 0.301
# Mean genetic distance 2.162, standard deviation 0.337
# Population of 500 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   21   449   4900.0    0.301     1
#      2    0    51       --       --     0
# Total extinctions: 0
# Generation time: 1.325 sec (1.473 average)
#
#  ****** Running generation 22 ******
#
# Population's average fitness: 1753.20000 stdev: 743.75383
# Best fitness: 4700.00000 - size: (6, 42) - species 1 - id 11455
# Average adjusted fitness: 0.355
# Mean genetic distance 2.142, standard deviation 0.330
# Population of 500 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   22   283   4700.0    0.343     2
#      2    1   217   3600.0    0.366     0
# Total extinctions: 0
# Generation time: 1.376 sec (1.477 average)
#
#  ****** Running generation 23 ******
#
# Population's average fitness: 1766.60000 stdev: 769.87300
# Best fitness: 5500.00000 - size: (4, 38) - species 1 - id 11791
# Average adjusted fitness: 0.283
# Mean genetic distance 2.026, standard deviation 0.267
# Population of 500 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   23   161   5500.0    0.278     3
#      2    2   339   4500.0    0.287     0
# Total extinctions: 0
# Generation time: 1.348 sec (1.476 average)
#
#  ****** Running generation 24 ******
#
# Population's average fitness: 1704.80000 stdev: 697.06310
# Best fitness: 4900.00000 - size: (4, 38) - species 1 - id 12141
# Average adjusted fitness: 0.338
# Mean genetic distance 2.023, standard deviation 0.259
# Population of 500 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   24   331   4900.0    0.350     4
#      2    3   169   4500.0    0.327     1
# Total extinctions: 0
# Generation time: 1.934 sec (1.536 average)
#
#  ****** Running generation 25 ******
#
# Population's average fitness: 1748.60000 stdev: 742.73686
# Best fitness: 4900.00000 - size: (5, 32) - species 2 - id 12550
# Average adjusted fitness: 0.328
# Mean genetic distance 1.980, standard deviation 0.233
# Population of 500 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   25   215   4800.0    0.333     5
#      2    4   285   4900.0    0.322     0
# Total extinctions: 0
# Generation time: 2.190 sec (1.576 average)
#
#  ****** Running generation 26 ******
#
# Population's average fitness: 1690.00000 stdev: 745.98928
# Best fitness: 5500.00000 - size: (4, 38) - species 1 - id 13106
# Average adjusted fitness: 0.309
# Mean genetic distance 1.962, standard deviation 0.253
# Population of 500 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   26   135   5500.0    0.317     6
#      2    5   365   5000.0    0.300     0
# Total extinctions: 0
# Generation time: 1.309 sec (1.476 average)
#
#  ****** Running generation 27 ******
#
# Population's average fitness: 1730.80000 stdev: 756.23499
# Best fitness: 6600.00000 - size: (5, 33) - species 2 - id 13256
# Average adjusted fitness: 0.216
# Mean genetic distance 1.981, standard deviation 0.261
# Population of 500 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   27   331   4100.0    0.220     7
#      2    6   169   6600.0    0.213     0
# Total extinctions: 0
# Generation time: 1.332 sec (1.476 average)
#
#  ****** Running generation 28 ******
#
# Population's average fitness: 1710.00000 stdev: 773.65367
# Best fitness: 6400.00000 - size: (4, 32) - species 1 - id 14196
# Average adjusted fitness: 0.233
# Mean genetic distance 2.012, standard deviation 0.258
# Population of 500 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   28   326   6400.0    0.228     0
#      2    7   174   4500.0    0.237     1
# Total extinctions: 0
# Generation time: 1.471 sec (1.494 average)
#
#  ****** Running generation 29 ******
#
# Population's average fitness: 1750.60000 stdev: 771.34923
# Best fitness: 7000.00000 - size: (4, 29) - species 1 - id 14745
# Average adjusted fitness: 0.251
# Mean genetic distance 1.991, standard deviation 0.255
# Population of 500 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   29   277   7000.0    0.248     0
#      2    8   223   4100.0    0.255     2
# Total extinctions: 0
# Generation time: 1.335 sec (1.494 average)
#
#  ****** Running generation 30 ******
#
# Population's average fitness: 1757.40000 stdev: 763.57399
# Best fitness: 4700.00000 - size: (4, 33) - species 2 - id 15022
# Average adjusted fitness: 0.331
# Mean genetic distance 2.012, standard deviation 0.269
# Population of 500 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   30   245   4100.0    0.336     1
#      2    9   255   4700.0    0.326     3
# Total extinctions: 0
# Generation time: 1.359 sec (1.498 average)
#
#  ****** Running generation 31 ******
#
# Population's average fitness: 1798.40000 stdev: 789.02309
# Best fitness: 6300.00000 - size: (5, 29) - species 2 - id 15699
# Average adjusted fitness: 0.250
# Mean genetic distance 2.039, standard deviation 0.266
# Population of 500 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   31   228   4500.0    0.251     2
#      2   10   272   6300.0    0.249     4
# Total extinctions: 0
# Generation time: 1.364 sec (1.502 average)
#
#  ****** Running generation 32 ******
#
# Population's average fitness: 1846.40000 stdev: 873.98343
# Best fitness: 8100.00000 - size: (5, 31) - species 1 - id 16281
# Average adjusted fitness: 0.207
# Mean genetic distance 2.114, standard deviation 0.283
# Population of 500 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   32   231   8100.0    0.194     0
#      2   11   269   6100.0    0.220     5
# Total extinctions: 0
# Generation time: 1.354 sec (1.500 average)
#
#  ****** Running generation 33 ******
#
# Population's average fitness: 1835.40000 stdev: 799.95427
# Best fitness: 6500.00000 - size: (5, 31) - species 1 - id 16281
# Average adjusted fitness: 0.236
# Mean genetic distance 2.158, standard deviation 0.317
# Population of 500 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   33    50   6500.0    0.242     1
#      2   12   450   5300.0    0.229     6
# Total extinctions: 0
# Generation time: 2.297 sec (1.594 average)
#
#  ****** Running generation 34 ******
#
# Population's average fitness: 1763.80000 stdev: 734.54037
# Best fitness: 5400.00000 - size: (7, 41) - species 2 - id 17087
# Average adjusted fitness: 0.272
# Mean genetic distance 2.097, standard deviation 0.333
# Population of 500 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   34   102   3800.0    0.270     2
#      2   13   398   5400.0    0.273     7
# Total extinctions: 0
# Generation time: 1.842 sec (1.585 average)
#
#  ****** Running generation 35 ******
#
# Population's average fitness: 1782.80000 stdev: 777.73013
# Best fitness: 4700.00000 - size: (4, 27) - species 2 - id 17881
# Average adjusted fitness: 0.361
# Mean genetic distance 2.065, standard deviation 0.298
# Population of 500 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   35   114   3600.0    0.352     3
#      2   14   386   4700.0    0.369     8
# Total extinctions: 0
# Generation time: 1.343 sec (1.501 average)
#
#  ****** Running generation 36 ******
#
# Population's average fitness: 1739.40000 stdev: 782.78199
# Best fitness: 4900.00000 - size: (6, 40) - species 2 - id 18384
# Average adjusted fitness: 0.346
# Traceback (most recent call last):
#   File "/content/2048-Game-For-CS470/main.py", line 425, in <module>
#     winner = run_neat(config_file)
#   File "/content/2048-Game-For-CS470/main.py", line 379, in run_neat
#     winner = p.run(eval_genome, 1000)
#   File "/usr/local/lib/python3.10/dist-packages/neat/population.py", line 110, in run
#     self.population = self.reproduction.reproduce(self.config, self.species,
#   File "/usr/local/lib/python3.10/dist-packages/neat/reproduction.py", line 183, in reproduce
#     child.configure_crossover(parent1, parent2, config.genome_config)
#   File "/usr/local/lib/python3.10/dist-packages/neat/genome.py", line 244, in configure_crossover
#     for key, cg1 in iteritems(parent1.connections):
#   File "/usr/local/lib/python3.10/dist-packages/neat/six_util.py", line 14, in iteritems
#     return iter(d.items(**kw))
# KeyboardInterrupt
# ^C
