# %% [markdown]
# <a href="https://colab.research.google.com/github/NelsonDane/2048-Game-For-CS470/blob/main/collab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content
# !git clone https://github.com/NelsonDane/2048-Game-For-CS470.git
# %cd 2048-Game-For-CS470/
# !git pull
# !pip install -r requirements.txt

# !python main.py
# Out:
# /content
# fatal: destination path '2048-Game-For-CS470' already exists and is not an empty directory.
# /content/2048-Game-For-CS470
# Already up to date.
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.1/58.1 kB 2.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.2/44.2 kB 1.8 MB/s eta 0:00:00
# ...
#
#  ****** Running generation 0 ******
#
# Population's average fitness: 1629.00000 stdev: 641.82474
# Best fitness: 4700.00000 - size: (4, 64) - species 1 - id 358
# Average adjusted fitness: 0.286
# Mean genetic distance 1.380, standard deviation 0.229
# Population of 500 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    0   500   4700.0    0.286     0
# Total extinctions: 0
# Generation time: 1.321 sec
#
#  ****** Running generation 1 ******
#
# Population's average fitness: 1621.20000 stdev: 679.49287
# Best fitness: 4500.00000 - size: (4, 63) - species 1 - id 702
# Average adjusted fitness: 0.331
# ...
