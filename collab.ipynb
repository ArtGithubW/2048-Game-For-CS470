# %% [markdown]
# <a href="https://colab.research.google.com/github/NelsonDane/2048-Game-For-CS470/blob/main/collab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
  import google.colab
  print("Running in Google Colab")
  # !git clone https://github.com/NelsonDane/2048-Game-For-CS470.git
  # %cd 2048-Game-For-CS470/
  # !pip install keyboard neat-python
except ImportError:
  print("Not Running in Google Colab")

import tkinter as tk
import random
from config import *
import sys
import keyboard as kb
import neat
import os

class Game(tk.Frame):
    def __init__(self, INIT_HEADLESS=None, INIT_TRAINING=None):

        self.HEADLESS = HEADLESS if INIT_HEADLESS is None else INIT_HEADLESS
        self.TRAINING = TRAINING if INIT_TRAINING is None else INIT_TRAINING

        if self.HEADLESS:
            self.start_game()
            if not TRAINING:
                while True:
                    self.on_arrow_key()

        else:
            tk.Frame.__init__(self)
            self.grid()
            self.master.title('Gaming Gamer Gaming Games')

            self.main_grid = tk.Frame(
                self, bg=GRID_COLOR, bd=3, width=600, height=600)
            self.main_grid.grid(pady=(80, 0))
            self.Init_GUI(self.HEADLESS)



            self.master.bind("<Left>", self.left)
            self.master.bind("<Right>", self.right)
            self.master.bind("<Up>", self.up)
            self.master.bind("<Down>", self.down)
            self.start_game()

            self.mainloop()

    def Init_GUI(self,Headless) -> None:
        if Headless:
            pass
        else:
            self.cells = []
            for i in range(4):
                row = []
                for j in range(4):
                    cell_frame = tk.Frame(
                        self.main_grid,
                        bg=EMPTY_COLOR,
                        width=120,
                        height=120)
                    cell_frame.grid(row=i, column=j, padx=5, pady=5)
                    cell_number = tk.Label(self.main_grid, bg=EMPTY_COLOR)
                    cell_number.grid(row=i, column=j)
                    cell_data = {"frame": cell_frame, "number": cell_number}
                    row.append(cell_data)
                self.cells.append(row)

            # make score header
            score_frame = tk.Frame(self)
            score_frame.place(relx=0.5, y=40, anchor="center")
            tk.Label(
                score_frame,
                text="Score",
                font=SCORE_LABEL_FONT).grid(
                row=0)
            self.score_label = tk.Label(score_frame, text="0", font=SCORE_FONT)
            self.score_label.grid(row=1)

#! _________________________ Keyboard Interaction for Headless Usage _________________________
#? This shit gets removed when we are actually training DP model.
    def on_arrow_key(self):
        key_event = kb.read_event()
        if key_event.event_type == kb.KEY_DOWN:
            if key_event.name == 'up':
                self.up(None)
            elif key_event.name == 'down':
                self.down(None)
            elif key_event.name == 'left':
                self.left(None)
            elif key_event.name == 'right':
                self.right(None)

#! _________________________ INIT Game _________________________
    """
        Inits the 4x4 Matrix full of 0s and randomly places 2 random cells with either a 2 or 4
    """
    def start_game(self) -> None:
        # create 2D 4x4 matrix of zeroes
        if self.HEADLESS:
            self.matrix = [[0] * 4 for _ in range(4)]

            # fill 2 random cells with 2s
            row = random.randint(0, 3)
            col = random.randint(0, 3)
            self.matrix[row][col] = random.choice([2, 4])
            while(self.matrix[row][col] != 0):
                row = random.randint(0, 3)
                col = random.randint(0, 3)
            self.matrix[row][col] = random.choice([2, 4])
        else:
            self.matrix = [[0] * 4 for _ in range(4)]
            # fill 2 random cells with 2s
            row = random.randint(0, 3)
            col = random.randint(0, 3)
            self.matrix[row][col] = random.choice([2, 4])
            self.cells[row][col]["frame"].configure(bg=BLOCK_COLORS[2])
            self.cells[row][col]["number"].configure(
                bg=BLOCK_COLORS[2],
                fg=BLOCK_NUM_COLORS[2],
                font=BLOCK_NUMBER_FONTS[2],
                text="2")
            while(self.matrix[row][col] != 0):
                    row = random.randint(0, 3)
                    col = random.randint(0, 3)
            self.matrix[row][col] = random.choice([2, 4])
            self.cells[row][col]["frame"].configure(bg=BLOCK_COLORS[2])
            self.cells[row][col]["number"].configure(
                bg=BLOCK_COLORS[2],
                fg=BLOCK_NUM_COLORS[2],
                font=BLOCK_NUMBER_FONTS[2],
                text="2")
        self.score = 0
        if not self.TRAINING:
            for row in range(len(self.matrix)):
                print(self.matrix[row])

#! _________________________ Possible Move Checker _________________________

    def horizontal_move_exists(self) -> bool:
        for i in range(4):
            for j in range(3):
                if self.matrix[i][j] == self.matrix[i][j + 1]:
                    return True
        return False


    def vertical_move_exists(self) -> bool:
        for i in range(3):
            for j in range(4):
                if self.matrix[i][j] == self.matrix[i + 1][j]:
                    return True
        return False

#!_________________________ Random Tile Function _________________________

    def add_new_tile(self) -> None:
        #* Checks for if no space is availiable for a new tile to spawn
        if all(element != 0 for row in self.matrix for element in row):
            if not TRAINING:
                print("NO SPACE")
            return None

        #* randomly selects a tile to spawn new tile. Will only spawn tile if tile empty -> (0)
        row = random.randint(0, 3)
        col = random.randint(0, 3)
        while(self.matrix[row][col] != 0):
            row = random.randint(0, 3)
            col = random.randint(0, 3)
        self.matrix[row][col] = random.choice([2, 4])


#!_________________________ Update the GUI to match the matrix _________________________

    def update_GUI(self) -> None:
        if self.HEADLESS:
            if not self.TRAINING:
                print("===============")
                for row in range(len(self.matrix)):
                    print(self.matrix[row])
                print("===============")
        else:
            for i in range(len(self.matrix)):
                for j in range(len(self.matrix[0])):
                    cell_value = self.matrix[i][j]
                    if cell_value == 0:
                        self.cells[i][j]["frame"].configure(bg=EMPTY_COLOR)
                        self.cells[i][j]["number"].configure(
                            bg=EMPTY_COLOR, text="")
                    else:
                        self.cells[i][j]["frame"].configure(
                            bg=BLOCK_COLORS[cell_value])
                        self.cells[i][j]["number"].configure(
                            bg=BLOCK_COLORS[cell_value],
                            fg=BLOCK_NUM_COLORS[cell_value],
                            font=BLOCK_NUMBER_FONTS[cell_value],
                            text=str(cell_value))
            self.score_label.configure(text=self.score)
            self.update_idletasks()


#! _________________________ Arrow-Press and Matrix Manipulation Code_________________________
#* Suddenly I want brisket

    """
    All functions below creates a False 4x4 matrix to merge the possible same integers on the called upon
    direction. If the int have been successfully merged then the bool at the cell turns True.

    Parameters can be None because of TKinter's way of calling master bind function
    Also checks if game is over first to prevent edge cases
    """
    def left(self,event:None):
        self.game_over()
        merged = [[False for _ in range(4)] for _ in range(4)]
        for i in range(len(self.matrix)):
            for j in range(len(self.matrix[0])):
                shift = 0
                for q in range(j):
                    if self.matrix[i][q] == 0:
                        shift += 1
                if shift > 0:
                    self.matrix[i][j - shift] = self.matrix[i][j]
                    self.matrix[i][j] = 0
                if self.matrix[i][j - shift] == self.matrix[i][j - shift - 1] and not merged[i][j - shift - 1] \
                        and not merged[i][j - shift]:
                    self.matrix[i][j - shift - 1] *= 2
                    self.score += self.matrix[i][j - shift - 1]
                    self.matrix[i][j - shift] = 0
                    merged[i][j - shift - 1] = True
        self.add_new_tile()
        self.update_GUI()


    def right(self, event:None):
        self.game_over()
        merged = [[False for _ in range(4)] for _ in range(4)]
        for i in range(len(self.matrix)):
            for j in range(len(self.matrix[0])):
                shift = 0
                for q in range(j):
                    if self.matrix[i][3 - q] == 0:
                        shift += 1
                if shift > 0:
                    self.matrix[i][3 - j + shift] = self.matrix[i][3 - j]
                    self.matrix[i][3 - j] = 0
                if 4 - j + shift <= 3:
                    if self.matrix[i][4 - j + shift] == self.matrix[i][3 - j + shift] and not merged[i][4 - j + shift] \
                            and not merged[i][3 - j + shift]:
                        self.matrix[i][4 - j + shift] *= 2
                        self.score += self.matrix[i][4 - j + shift]
                        self.matrix[i][3 - j + shift] = 0
                        merged[i][4 - j + shift] = True
        self.add_new_tile()
        self.update_GUI()

    def up(self, event:None):
        self.game_over()
        merged = [[False for _ in range(4)] for _ in range(4)]
        for i in range(len(self.matrix)):
            for j in range(len(self.matrix[0])):
                shift = 0
                if i > 0:
                    for q in range(i):
                        if self.matrix[q][j] == 0:
                            shift += 1
                    if shift > 0:
                        self.matrix[i - shift][j] = self.matrix[i][j]
                        self.matrix[i][j] = 0
                    if self.matrix[i - shift - 1][j] == self.matrix[i - shift][j] and not merged[i - shift][j] \
                            and not merged[i - shift - 1][j]:
                        self.matrix[i - shift - 1][j] *= 2
                        self.score += self.matrix[i - shift - 1][j]
                        self.matrix[i - shift][j] = 0
                        merged[i - shift - 1][j] = True
        self.add_new_tile()
        self.update_GUI()

    def down(self,event:None):
        self.game_over()
        merged = [[False for _ in range(4)] for _ in range(4)]
        for i in range(3):
            for j in range(4):
                shift = 0
                for q in range(i + 1):
                    if self.matrix[3 - q][j] == 0:
                        shift += 1
                if shift > 0:
                    self.matrix[2 - i + shift][j] = self.matrix[2 - i][j]
                    self.matrix[2 - i][j] = 0
                if 3 - i + shift <= 3:
                    if self.matrix[2 - i + shift][j] == self.matrix[3 - i + shift][j] and not merged[3 - i + shift][j] \
                            and not merged[2 - i + shift][j]:
                        self.matrix[3 - i + shift][j] *= 2
                        self.score += self.matrix[3 - i + shift][j]
                        self.matrix[2 - i + shift][j] = 0
                        merged[3 - i + shift][j] = True
        self.add_new_tile()
        self.update_GUI()


#! _________________________  Result _________________________
    """
    This destroys the window if user achieves 2048 in ANY of the cells
    OR there is no valid move available
    """
    def game_over(self) -> bool:
        is_game_over = False
        if any(2048 in row for row in self.matrix):
            # print("Win")
            # sys.exit()
            if not self.HEADLESS:
                self.master.destroy()
            is_game_over = True
        elif not any(0 in row for row in self.matrix) and not self.horizontal_move_exists() and not self.vertical_move_exists():
            # print("Lose")
            # sys.exit()
            if not self.HEADLESS:
                self.master.destroy()
            is_game_over = True
        return is_game_over

    def flatten_board_to_list(self) -> list:
        return [element for row in self.matrix for element in row]

    def get_highest_tile(self) -> int:
        return max(max(row) for row in self.matrix)


def eval_genome(genomes, config):
    neural_nets = []
    for _, genome in genomes:
        genome.fitness = 0
        net = neat.nn.FeedForwardNetwork.create(genome, config)
        neural_nets.append((net, genome))

    for net, genome in neural_nets:
        game = Game()
        moves_stuck = 0
        prev_score = 0
        seen_states = list()
        while not game.game_over():
            inputs = game.flatten_board_to_list()
            output = net.activate(inputs)
            move = output.index(max(output))
            # Make a move
            if move == 0:
                game.left(None)
            elif move == 1:
                game.right(None)
            elif move == 2:
                game.up(None)
            elif move == 3:
                game.down(None)
            # Don't let the game get stuck
            if game.score == prev_score:
                moves_stuck += 1
            else:
                moves_stuck = 0
            if moves_stuck > 10:
                # We HATE getting stuck
                # genome.fitness *= 0.2
                break
            # Reward the genome for increasing the score
            if game.score > prev_score:
                genome.fitness += 100
            # else:
            #     genome.fitness -= 1
            prev_score = game.score
            # Penalize the genome for repeating the same states
            # if game.flatten_board_to_list() in seen_states:
            #     genome.fitness += -10
            # if game.flatten_board_to_list() not in seen_states:
            #     seen_states.append(game.flatten_board_to_list())

        # Reward for finishing nicely
        # if game.game_over():
        #     genome.fitness += 100
    return genome.fitness

def run_neat(config_file):
    config = neat.config.Config(neat.DefaultGenome, neat.DefaultReproduction,
                                neat.DefaultSpeciesSet, neat.DefaultStagnation,
                                config_file)
    p = neat.Population(config)
    p.add_reporter(neat.StdOutReporter(True))
    stats = neat.StatisticsReporter()
    p.add_reporter(stats)

    winner = p.run(eval_genome, 100)
    return winner

def play_with_winner(winner, config_file):
    config = neat.config.Config(neat.DefaultGenome, neat.DefaultReproduction,
                                neat.DefaultSpeciesSet, neat.DefaultStagnation,
                                config_file)
    net = neat.nn.FeedForwardNetwork.create(winner, config)

    game = Game(INIT_HEADLESS=True, INIT_TRAINING=False)

    print("Playing with winner")
    previous_score = 0
    moves_without_score_increase = 0
    while not game.game_over():
        inputs = game.flatten_board_to_list()
        output = net.activate(inputs)
        move = output.index(max(output))
        if move == 0:
            game.left(None)
        elif move == 1:
            game.right(None)
        elif move == 2:
            game.up(None)
        elif move == 3:
            game.down(None)
        # game.update_GUI()
        # Don't get stuck
        if game.score == previous_score:
            moves_without_score_increase += 1
        else:
            moves_without_score_increase = 0
        if moves_without_score_increase > 10:
            print("Stuck")
            break
        previous_score = game.score

    # game.update_GUI()
    print(f"Score: {game.score}")
    print(f"Highest Tile: {game.get_highest_tile()}")

if __name__ == "__main__":
    if not TRAINING:
        Game()
    else:
        config_file = "./neat_config"
        winner = run_neat(config_file)
        # print(winner)
        play_with_winner(winner, config_file)
# Out:
# Cloning into '2048-Game-For-CS470'...
# remote: Enumerating objects: 33, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 33 (delta 8), reused 25 (delta 7), pack-reused 0 (from 0)
# Receiving objects: 100% (33/33), 20.92 KiB | 2.99 MiB/s, done.
# Resolving deltas: 100% (8/8), done.
# /content/2048-Game-For-CS470/2048-Game-For-CS470
# Requirement already satisfied: keyboard in /usr/local/lib/python3.10/dist-packages (0.13.5)
# Requirement already satisfied: neat-python in /usr/local/lib/python3.10/dist-packages (0.92)
# collab.ipynb  config.py  main.py  neat_config  README.md  requirements.txt
#
#  ****** Running generation 0 ******
#
# Population's average fitness: 1646.80000 stdev: 681.74024
# Best fitness: 4200.00000 - size: (4, 64) - species 1 - id 333
# Average adjusted fitness: 0.345
# Mean genetic distance 1.307, standard deviation 0.227
# Population of 500 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    0   500   4200.0    0.345     0
# Total extinctions: 0
# Generation time: 1.690 sec
#
#  ****** Running generation 1 ******
#
# Population's average fitness: 1608.60000 stdev: 685.14673
# Best fitness: 6200.00000 - size: (5, 60) - species 1 - id 750
# Average adjusted fitness: 0.247
# Mean genetic distance 1.308, standard deviation 0.223
# Population of 500 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    1   500   6200.0    0.247     0
# Total extinctions: 0
# Generation time: 1.615 sec (1.653 average)
#
#  ****** Running generation 2 ******
#
# Population's average fitness: 1634.20000 stdev: 663.90538
# Best fitness: 4400.00000 - size: (4, 63) - species 1 - id 1048
# Average adjusted fitness: 0.325
# Mean genetic distance 1.346, standard deviation 0.230
# Population of 500 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    2   500   4400.0    0.325     1
# Total extinctions: 0
# Generation time: 1.398 sec (1.568 average)
#
#  ****** Running generation 3 ******
#
# Population's average fitness: 1664.80000 stdev: 657.96729
# Best fitness: 5200.00000 - size: (4, 59) - species 1 - id 1674
# Average adjusted fitness: 0.279
# Mean genetic distance 1.434, standard deviation 0.231
# Population of 500 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    3   500   5200.0    0.279     2
# Total extinctions: 0
# Generation time: 2.160 sec (1.716 average)
#
#  ****** Running generation 4 ******
#
# Population's average fitness: 1715.20000 stdev: 692.27809
# Best fitness: 4900.00000 - size: (6, 59) - species 1 - id 2448
# Average adjusted fitness: 0.350
# Mean genetic distance 1.534, standard deviation 0.209
# Population of 500 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    4   500   4900.0    0.350     3
# Total extinctions: 0
# Generation time: 2.215 sec (1.816 average)
#
#  ****** Running generation 5 ******
#
# Population's average fitness: 1679.80000 stdev: 703.00211
# Best fitness: 4800.00000 - size: (4, 53) - species 1 - id 2890
# Average adjusted fitness: 0.336
# Mean genetic distance 1.528, standard deviation 0.218
# Population of 500 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    5   500   4800.0    0.336     4
# Total extinctions: 0
# Generation time: 1.427 sec (1.751 average)
#
#  ****** Running generation 6 ******
#
# Population's average fitness: 1746.20000 stdev: 750.41692
# Best fitness: 5200.00000 - size: (4, 53) - species 1 - id 3000
# Average adjusted fitness: 0.295
# Mean genetic distance 1.541, standard deviation 0.232
# Population of 500 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    6   500   5200.0    0.295     5
# Total extinctions: 0
# Generation time: 1.633 sec (1.734 average)
#
#  ****** Running generation 7 ******
#
# Population's average fitness: 1706.00000 stdev: 691.00217
# Best fitness: 4500.00000 - size: (4, 53) - species 1 - id 3519
# Average adjusted fitness: 0.335
# Mean genetic distance 1.631, standard deviation 0.245
# Population of 500 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    7   500   4500.0    0.335     6
# Total extinctions: 0
# Generation time: 1.377 sec (1.689 average)
#
#  ****** Running generation 8 ******
#
# Population's average fitness: 1732.20000 stdev: 731.39809
# Best fitness: 5600.00000 - size: (4, 50) - species 1 - id 4088
# Average adjusted fitness: 0.297
# Mean genetic distance 1.788, standard deviation 0.276
# Population of 500 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    8   500   5600.0    0.297     7
# Total extinctions: 0
# Generation time: 1.597 sec (1.679 average)
#
#  ****** Running generation 9 ******
#
# Population's average fitness: 1718.20000 stdev: 716.60921
# Best fitness: 4400.00000 - size: (5, 50) - species 1 - id 4900
# Average adjusted fitness: 0.391
# Mean genetic distance 1.834, standard deviation 0.251
# Population of 500 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    9   500   4400.0    0.391     8
# Total extinctions: 0
# Generation time: 1.397 sec (1.651 average)
#
#  ****** Running generation 10 ******
#
# Population's average fitness: 1646.20000 stdev: 677.79463
# Best fitness: 4700.00000 - size: (4, 41) - species 1 - id 5171
# Average adjusted fitness: 0.336
# Mean genetic distance 1.780, standard deviation 0.278
# Population of 500 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   10   500   4700.0    0.336     9
# Total extinctions: 0
# Generation time: 1.549 sec (1.637 average)
#
#  ****** Running generation 11 ******
#
# Population's average fitness: 1691.00000 stdev: 716.58845
# Best fitness: 5100.00000 - size: (4, 49) - species 1 - id 5695
# Average adjusted fitness: 0.318
# Mean genetic distance 1.802, standard deviation 0.267
# Population of 500 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   11   500   5100.0    0.318    10
# Total extinctions: 0
# Generation time: 1.994 sec (1.675 average)
#
#  ****** Running generation 12 ******
#
# Population's average fitness: 1766.80000 stdev: 772.74689
# Best fitness: 5600.00000 - size: (5, 41) - species 1 - id 6238
# Average adjusted fitness: 0.277
# Mean genetic distance 1.787, standard deviation 0.260
# Population of 500 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   12   500   5600.0    0.277    11
# Total extinctions: 0
# Generation time: 2.173 sec (1.752 average)
#
#  ****** Running generation 13 ******
#
# Population's average fitness: 1704.80000 stdev: 674.34187
# Best fitness: 4400.00000 - size: (4, 42) - species 1 - id 6857
# Average adjusted fitness: 0.358
# Mean genetic distance 1.917, standard deviation 0.362
# Population of 500 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   13   493   4400.0    0.358    12
#      2    0     7       --       --     0
# Total extinctions: 0
# Generation time: 1.546 sec (1.691 average)
#
#  ****** Running generation 14 ******
#
# Population's average fitness: 1739.00000 stdev: 712.64227
# Best fitness: 4200.00000 - size: (4, 47) - species 1 - id 7040
# Average adjusted fitness: 0.341
# Mean genetic distance 2.131, standard deviation 0.466
# Population of 500 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   14   423   4200.0    0.370    13
#      2    1    77   2400.0    0.311     0
# Total extinctions: 0
# Generation time: 1.384 sec (1.608 average)
#
#  ****** Running generation 15 ******
#
# Population's average fitness: 1631.20000 stdev: 682.39766
# Best fitness: 5000.00000 - size: (6, 46) - species 1 - id 7962
# Average adjusted fitness: 0.305
# Mean genetic distance 2.116, standard deviation 0.447
# Population of 500 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   15   316   5000.0    0.316    14
#      2    2   184   4300.0    0.294     0
# Total extinctions: 0
# Generation time: 1.552 sec (1.620 average)
#
#  ****** Running generation 16 ******
#
# Population's average fitness: 1664.80000 stdev: 710.21191
# Best fitness: 5300.00000 - size: (5, 46) - species 1 - id 8046
# Average adjusted fitness: 0.311
# Mean genetic distance 2.057, standard deviation 0.362
# Population of 500 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   16   349   5300.0    0.322    15
#      2    3   151   3500.0    0.301     1
# Total extinctions: 0
# Generation time: 1.360 sec (1.593 average)
#
#  ****** Running generation 17 ******
#
# Population's average fitness: 1662.20000 stdev: 677.34124
# Best fitness: 5300.00000 - size: (4, 47) - species 1 - id 8976
# Average adjusted fitness: 0.273
# Mean genetic distance 2.057, standard deviation 0.363
# Population of 500 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   17   357   5300.0    0.271    16
#      2    4   143   4000.0    0.276     2
# Total extinctions: 0
# Generation time: 1.392 sec (1.594 average)
#
#  ****** Running generation 18 ******
#
# Population's average fitness: 1736.40000 stdev: 672.18676
# Best fitness: 4400.00000 - size: (4, 35) - species 1 - id 9197
# Average adjusted fitness: 0.354
# Mean genetic distance 2.045, standard deviation 0.363
# Population of 500 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   18   411   4400.0    0.345    17
#      2    5    89   4300.0    0.364     3
# Total extinctions: 0
# Generation time: 1.609 sec (1.596 average)
#
#  ****** Running generation 19 ******
#
# Population's average fitness: 1748.60000 stdev: 688.60587
# Best fitness: 4200.00000 - size: (4, 43) - species 2 - id 9545
# Average adjusted fitness: 0.421
# Mean genetic distance 2.036, standard deviation 0.373
# Population of 500 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   19   325   4100.0    0.414    18
#      2    6   175   4200.0    0.428     4
# Total extinctions: 0
# Generation time: 1.884 sec (1.644 average)
#
#  ****** Running generation 20 ******
#
# Population's average fitness: 1697.00000 stdev: 737.32693
# Best fitness: 5400.00000 - size: (4, 43) - species 1 - id 10228
# Average adjusted fitness: 0.272
# Mean genetic distance 2.058, standard deviation 0.348
# Population of 500 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   20   287   5400.0    0.278    19
#      2    7   213   3900.0    0.266     5
# Total extinctions: 0
# Generation time: 2.461 sec (1.736 average)
#
#  ****** Running generation 21 ******
#
# Population's average fitness: 1667.00000 stdev: 716.91771
# Best fitness: 5800.00000 - size: (5, 38) - species 2 - id 10504
# Average adjusted fitness: 0.275
# Mean genetic distance 2.017, standard deviation 0.303
# Population of 500 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   21   301   4200.0    0.276    20
#      2    8   199   5800.0    0.273     0
# Total extinctions: 0
# Generation time: 1.333 sec (1.669 average)
#
#  ****** Running generation 22 ******
#
# Population's average fitness: 1701.40000 stdev: 731.06637
# Best fitness: 4700.00000 - size: (4, 38) - species 1 - id 11132
# Average adjusted fitness: 0.361
# Mean genetic distance 2.029, standard deviation 0.311
# Population of 500 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   22   224   4700.0    0.368    21
#      2    9   276   4300.0    0.353     1
# Total extinctions: 0
# Generation time: 1.351 sec (1.587 average)
#
#  ****** Running generation 23 ******
#
# Population's average fitness: 1667.20000 stdev: 720.55823
# Best fitness: 5300.00000 - size: (5, 39) - species 1 - id 11831
# Average adjusted fitness: 0.315
# Mean genetic distance 2.016, standard deviation 0.279
# Population of 500 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   23   194   5300.0    0.324    22
#      2   10   306   4200.0    0.307     2
# Total extinctions: 0
# Generation time: 1.495 sec (1.582 average)
#
#  ****** Running generation 24 ******
#
# Population's average fitness: 1681.00000 stdev: 700.38489
# Best fitness: 6000.00000 - size: (4, 34) - species 1 - id 12245
# Average adjusted fitness: 0.282
# Mean genetic distance 2.068, standard deviation 0.283
# Population of 500 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   24   225   6000.0    0.288    23
#      2   11   275   4300.0    0.275     3
# Total extinctions: 0
# Generation time: 1.316 sec (1.575 average)
#
#  ****** Running generation 25 ******
#
# Population's average fitness: 1703.80000 stdev: 698.28759
# Best fitness: 4900.00000 - size: (4, 34) - species 1 - id 12727
# Average adjusted fitness: 0.321
# Mean genetic distance 2.066, standard deviation 0.287
# Population of 500 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   25   357   4900.0    0.330    24
#      2   12   143   3900.0    0.312     4
# Total extinctions: 0
# Generation time: 1.521 sec (1.572 average)
#
#  ****** Running generation 26 ******
#
# Population's average fitness: 1679.20000 stdev: 707.62092
# Best fitness: 4700.00000 - size: (5, 38) - species 1 - id 13232
# Average adjusted fitness: 0.327
# Mean genetic distance 2.042, standard deviation 0.279
# Population of 500 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   26   288   4700.0    0.331    25
#      2   13   212   4600.0    0.324     5
# Total extinctions: 0
# Generation time: 1.324 sec (1.569 average)
#
#  ****** Running generation 27 ******
#
# Population's average fitness: 1728.80000 stdev: 711.03485
# Best fitness: 5600.00000 - size: (5, 32) - species 1 - id 13907
# Average adjusted fitness: 0.243
# Mean genetic distance 2.039, standard deviation 0.287
# Population of 500 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   27   315   5600.0    0.232    26
#      2   14   185   5100.0    0.253     6
# Total extinctions: 0
# Generation time: 1.446 sec (1.574 average)
#
#  ****** Running generation 28 ******
#
# Population's average fitness: 1759.40000 stdev: 714.48698
# Best fitness: 5800.00000 - size: (5, 32) - species 1 - id 13907
# Average adjusted fitness: 0.266
# Mean genetic distance 2.006, standard deviation 0.273
# Population of 500 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   28   235   5800.0    0.264    27
#      2   15   265   4200.0    0.268     7
# Total extinctions: 0
# Generation time: 2.657 sec (1.679 average)
#
#  ****** Running generation 29 ******
#
# Population's average fitness: 1667.80000 stdev: 679.34024
# Best fitness: 4500.00000 - size: (4, 29) - species 2 - id 14541
# Average adjusted fitness: 0.356
# Mean genetic distance 2.003, standard deviation 0.266
# Population of 500 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   29   396   4000.0    0.357    28
#      2   16   104   4500.0    0.356     8
# Total extinctions: 0
# Generation time: 1.508 sec (1.641 average)
#
#  ****** Running generation 30 ******
#
# Population's average fitness: 1683.00000 stdev: 695.22011
# Best fitness: 4400.00000 - size: (5, 34) - species 1 - id 15024
# Average adjusted fitness: 0.335
# Mean genetic distance 1.967, standard deviation 0.285
# Population of 500 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   30   267   4400.0    0.339    29
#      2   17   233   3600.0    0.330     9
# Total extinctions: 0
# Generation time: 1.516 sec (1.547 average)
#
#  ****** Running generation 31 ******
#
# Population's average fitness: 1653.60000 stdev: 690.57008
# Best fitness: 4600.00000 - size: (6, 35) - species 1 - id 15661
# Average adjusted fitness: 0.329
# Mean genetic distance 1.992, standard deviation 0.270
# Population of 500 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   31   353   4600.0    0.347    30
#      2   18   147   3600.0    0.311    10
# Total extinctions: 0
# Generation time: 1.311 sec (1.544 average)
#
#  ****** Running generation 32 ******
#
# Population's average fitness: 1648.40000 stdev: 684.70245
# Best fitness: 4600.00000 - size: (5, 35) - species 1 - id 16063
# Average adjusted fitness: 0.350
# Mean genetic distance 2.112, standard deviation 0.272
# Population of 500 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   32   369   4600.0    0.335    31
#      2   19   131   4400.0    0.366    11
# Total extinctions: 0
# Generation time: 1.317 sec (1.541 average)
#
#  ****** Running generation 33 ******
#
# Population's average fitness: 1733.40000 stdev: 710.25660
# Best fitness: 5400.00000 - size: (4, 25) - species 1 - id 16808
# Average adjusted fitness: 0.278
# Mean genetic distance 2.221, standard deviation 0.302
# Population of 500 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   33   392   5400.0    0.284    32
#      2   20   108   3700.0    0.272    12
# Total extinctions: 0
# Generation time: 1.521 sec (1.544 average)
#
#  ****** Running generation 34 ******
#
# Population's average fitness: 1714.80000 stdev: 749.94730
# Best fitness: 5700.00000 - size: (4, 34) - species 1 - id 17190
# Average adjusted fitness: 0.288
# Mean genetic distance 2.163, standard deviation 0.324
# Population of 500 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   34   380   5700.0    0.288    33
#      2   21   120   3600.0    0.288    13
# Total extinctions: 0
# Generation time: 1.317 sec (1.544 average)
#
#  ****** Running generation 35 ******
#
# Population's average fitness: 1685.40000 stdev: 783.91762
# Best fitness: 5100.00000 - size: (6, 30) - species 1 - id 17690
# Average adjusted fitness: 0.304
# Mean genetic distance 2.283, standard deviation 0.500
# Population of 500 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   35   327   5100.0    0.303    34
#      2   22   166   4300.0    0.304    14
#      3    0     7       --       --     0
# Total extinctions: 0
# Generation time: 1.533 sec (1.545 average)
#
#  ****** Running generation 36 ******
#
# Population's average fitness: 1692.60000 stdev: 747.82701
# Best fitness: 7000.00000 - size: (5, 36) - species 2 - id 17989
# Average adjusted fitness: 0.272
# Mean genetic distance 2.462, standard deviation 0.497
# Population of 500 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   36   248   4400.0    0.237    35
#      2   23   149   7000.0    0.248     0
#      3    1   103   3400.0    0.333     0
# Total extinctions: 0
# Generation time: 2.112 sec (1.624 average)
#
#  ****** Running generation 37 ******
#
# Population's average fitness: 1740.00000 stdev: 771.25871
# Best fitness: 5400.00000 - size: (4, 26) - species 1 - id 18524
# Average adjusted fitness: 0.327
# Mean genetic distance 2.461, standard deviation 0.464
# Population of 500 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   37   255   5400.0    0.314    36
#      2   24   134   4500.0    0.320     1
#      3    2   111   4200.0    0.346     0
# Total extinctions: 0
# Generation time: 2.031 sec (1.682 average)
#
#  ****** Running generation 38 ******
#
# Population's average fitness: 1763.00000 stdev: 764.52011
# Best fitness: 4700.00000 - size: (6, 31) - species 2 - id 18647
# Average adjusted fitness: 0.320
# Mean genetic distance 2.419, standard deviation 0.460
# Population of 500 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   38   281   4700.0    0.313    37
#      2   25   104   4700.0    0.298     2
#      3    3   115   3600.0    0.348     1
# Total extinctions: 0
# Generation time: 1.564 sec (1.573 average)
#
#  ****** Running generation 39 ******
#
# Population's average fitness: 1730.20000 stdev: 752.37488
# Best fitness: 5600.00000 - size: (5, 32) - species 1 - id 19668
# Average adjusted fitness: 0.273
# Mean genetic distance 2.375, standard deviation 0.439
# Population of 501 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   39   282   5600.0    0.263    38
#      2   26   112   3800.0    0.278     3
#      3    4   107   4600.0    0.279     0
# Total extinctions: 0
# Generation time: 1.346 sec (1.557 average)
#
#  ****** Running generation 40 ******
#
# Population's average fitness: 1777.24551 stdev: 768.20630
# Best fitness: 6100.00000 - size: (6, 33) - species 3 - id 20198
# Average adjusted fitness: 0.280
# Mean genetic distance 2.347, standard deviation 0.429
# Population of 500 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   40   316   5800.0    0.279    39
#      2   27    75   4600.0    0.266     4
#      3    5   109   6100.0    0.296     0
# Total extinctions: 0
# Generation time: 1.340 sec (1.539 average)
#
#  ****** Running generation 41 ******
#
# Population's average fitness: 1834.00000 stdev: 838.11932
# Best fitness: 5000.00000 - size: (5, 32) - species 3 - id 20793
# Average adjusted fitness: 0.335
# Mean genetic distance 2.304, standard deviation 0.429
# Population of 499 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   41   283   4700.0    0.343    40
#      2   28    98   4100.0    0.304     5
#      3    6   118   5000.0    0.357     1
# Total extinctions: 0
# Generation time: 1.579 sec (1.566 average)
#
#  ****** Running generation 42 ******
#
# Population's average fitness: 1789.57916 stdev: 761.58496
# Best fitness: 5100.00000 - size: (5, 27) - species 1 - id 21233
# Average adjusted fitness: 0.346
# Mean genetic distance 2.337, standard deviation 0.417
# Population of 500 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   42   177   5100.0    0.358    41
#      2   29   202   4500.0    0.327     6
#      3    7   121   4300.0    0.354     2
# Total extinctions: 0
# Generation time: 1.378 sec (1.572 average)
#
#  ****** Running generation 43 ******
#
# Population's average fitness: 1870.20000 stdev: 779.85381
# Best fitness: 5900.00000 - size: (5, 30) - species 3 - id 21548
# Average adjusted fitness: 0.294
# Mean genetic distance 2.389, standard deviation 0.453
# Population of 499 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   43   141   4700.0    0.317    42
#      2   30   244   4200.0    0.270     7
#      3    8   114   5900.0    0.296     3
# Total extinctions: 0
# Generation time: 1.566 sec (1.577 average)
#
#  ****** Running generation 44 ******
#
# Population's average fitness: 1795.79158 stdev: 777.23259
# Best fitness: 4600.00000 - size: (5, 31) - species 1 - id 22227
# Average adjusted fitness: 0.392
# Mean genetic distance 2.416, standard deviation 0.460
# Population of 499 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   44   178   4600.0    0.411    43
#      2   31   208   4400.0    0.382     8
#      3    9   113   4500.0    0.383     4
# Total extinctions: 0
# Generation time: 1.910 sec (1.636 average)
#
#  ****** Running generation 45 ******
#
# Population's average fitness: 1852.30461 stdev: 853.92510
# Best fitness: 6300.00000 - size: (6, 27) - species 1 - id 22819
# Average adjusted fitness: 0.295
# Mean genetic distance 2.457, standard deviation 0.484
# Population of 500 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   45   216   6300.0    0.303     0
#      2   32   174   5000.0    0.285     9
#      3   10   110   4900.0    0.296     5
# Total extinctions: 0
# Generation time: 2.179 sec (1.701 average)
#
#  ****** Running generation 46 ******
#
# Population's average fitness: 1846.20000 stdev: 836.59163
# Best fitness: 5800.00000 - size: (5, 24) - species 2 - id 23139
# Average adjusted fitness: 0.285
# Mean genetic distance 2.434, standard deviation 0.483
# Population of 500 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   46   164   4600.0    0.269     1
#      2   33   219   5800.0    0.281    10
#      3   11   117   4900.0    0.306     6
# Total extinctions: 0
# Generation time: 1.563 sec (1.646 average)
#
#  ****** Running generation 47 ******
#
# Population's average fitness: 1851.00000 stdev: 832.21331
# Best fitness: 5800.00000 - size: (7, 29) - species 2 - id 23475
# Average adjusted fitness: 0.297
# Mean genetic distance 2.422, standard deviation 0.479
# Population of 501 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   47   312   4300.0    0.293     2
#      2   34    74   5800.0    0.289    11
#      3   12   115   5800.0    0.307     7
# Total extinctions: 0
# Generation time: 1.368 sec (1.579 average)
#
#  ****** Running generation 48 ******
#
# Population's average fitness: 1862.67465 stdev: 854.65967
# Best fitness: 5500.00000 - size: (4, 21) - species 3 - id 24097
# Average adjusted fitness: 0.326
# Mean genetic distance 2.444, standard deviation 0.480
# Population of 501 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   48   284   5200.0    0.326     3
#      2   35   108   5500.0    0.324    12
#      3   13   109   5500.0    0.329     8
# Total extinctions: 0
# Generation time: 1.353 sec (1.558 average)
#
#  ****** Running generation 49 ******
#
# Population's average fitness: 1771.25749 stdev: 772.46283
# Best fitness: 7600.00000 - size: (4, 26) - species 3 - id 24751
# Average adjusted fitness: 0.206
# Mean genetic distance 2.456, standard deviation 0.520
# Population of 501 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   49   166   3700.0    0.192     4
#      2   36   221   4000.0    0.203    13
#      3   14   114   7600.0    0.224     0
# Total extinctions: 0
# Generation time: 1.723 sec (1.596 average)
#
#  ****** Running generation 50 ******
#
# Population's average fitness: 1874.25150 stdev: 812.89243
# Best fitness: 5500.00000 - size: (6, 21) - species 1 - id 24984
# Average adjusted fitness: 0.317
# Mean genetic distance 2.463, standard deviation 0.547
# Population of 501 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   50   229   5500.0    0.337     5
#      2   37   154   4400.0    0.302    14
#      3   15   118   4100.0    0.312     1
# Total extinctions: 0
# Generation time: 1.462 sec (1.608 average)
#
#  ****** Running generation 51 ******
#
# Population's average fitness: 1876.24750 stdev: 897.82099
# Best fitness: 7300.00000 - size: (4, 26) - species 3 - id 25518
# Average adjusted fitness: 0.235
# Mean genetic distance 2.462, standard deviation 0.564
# Population of 500 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   51   274   5800.0    0.241     6
#      2   38   113   5900.0    0.226    15
#      3   16   112   7300.0    0.239     2
#      4    0     1       --       --     0
# Total extinctions: 0
# Generation time: 1.549 sec (1.605 average)
#
#  ****** Running generation 52 ******
#
# Population's average fitness: 1868.80000 stdev: 908.77201
# Best fitness: 6400.00000 - size: (4, 31) - species 1 - id 25941
# Average adjusted fitness: 0.252
# Mean genetic distance 2.568, standard deviation 0.634
# Population of 500 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   52   210   6400.0    0.289     0
#      2   39   148   5300.0    0.278    16
#      3   17    80   4900.0    0.266     3
#      4    1    62   1200.0    0.175     0
# Total extinctions: 0
# Generation time: 2.507 sec (1.718 average)
#
#  ****** Running generation 53 ******
#
# Population's average fitness: 1917.20000 stdev: 836.60275
# Best fitness: 5800.00000 - size: (4, 26) - species 2 - id 26720
# Average adjusted fitness: 0.323
# Mean genetic distance 2.587, standard deviation 0.631
# Population of 501 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   53   278   5600.0    0.349     1
#      2   40    73   5800.0    0.325    17
#      3   18    69   4700.0    0.319     4
#      4    2    81   4100.0    0.299     0
# Total extinctions: 0
# Generation time: 2.220 sec (1.783 average)
#
#  ****** Running generation 54 ******
#
# Population's average fitness: 1905.38922 stdev: 871.54559
# Best fitness: 6400.00000 - size: (4, 23) - species 2 - id 27277
# Average adjusted fitness: 0.292
# Mean genetic distance 2.530, standard deviation 0.583
# Population of 501 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   54   215   4900.0    0.306     2
#      2   41   134   6400.0    0.302    18
#      3   19    91   4600.0    0.267     5
#      4    3    61   4700.0    0.291     0
# Total extinctions: 0
# Generation time: 1.639 sec (1.756 average)
#
#  ****** Running generation 55 ******
#
# Population's average fitness: 1899.40120 stdev: 803.74600
# Best fitness: 4500.00000 - size: (5, 30) - species 1 - id 27784
# Average adjusted fitness: 0.363
# Mean genetic distance 2.506, standard deviation 0.556
# Population of 501 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   55   152   4500.0    0.358     3
#      2   42   197   4100.0    0.377    19
#      3   20   101   4400.0    0.398     6
#      4    4    51   3300.0    0.321     1
# Total extinctions: 0
# Generation time: 1.585 sec (1.697 average)
#
#  ****** Running generation 56 ******
#
# Population's average fitness: 1821.55689 stdev: 772.20578
# Best fitness: 5600.00000 - size: (5, 19) - species 1 - id 28089
# Average adjusted fitness: 0.296
# Mean genetic distance 2.516, standard deviation 0.533
# Population of 501 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   56   275   5600.0    0.312     4
#      2   43    78   4300.0    0.299    20
#      3   21    94   4500.0    0.300     7
#      4    5    54   4000.0    0.271     2
# Total extinctions: 0
# Generation time: 3.247 sec (1.865 average)
#
#  ****** Running generation 57 ******
#
# Population's average fitness: 1802.19561 stdev: 808.00336
# Best fitness: 7300.00000 - size: (4, 23) - species 3 - id 28734
# Average adjusted fitness: 0.231
# Mean genetic distance 2.536, standard deviation 0.567
# Population of 500 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   57   258   3900.0    0.213     5
#      2   44    81   4100.0    0.230    21
#      3   22   107   7300.0    0.263     8
#      4    6    54   3900.0    0.217     3
# Total extinctions: 0
# Generation time: 2.557 sec (1.984 average)
#
#  ****** Running generation 58 ******
#
# Population's average fitness: 1909.80000 stdev: 907.46017
# Best fitness: 6800.00000 - size: (4, 25) - species 3 - id 29316
# Average adjusted fitness: 0.266
# Mean genetic distance 2.625, standard deviation 0.600
# Population of 500 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   58   203   4500.0    0.245     6
#      2   45   143   6200.0    0.257    22
#      3   23   108   6800.0    0.288     9
#      4    7    43   6200.0    0.273     0
#      5    0     3       --       --     0
# Total extinctions: 0
# Generation time: 2.247 sec (2.074 average)
#
#  ****** Running generation 59 ******
#
# Population's average fitness: 1849.80000 stdev: 865.34384
# Best fitness: 7900.00000 - size: (7, 30) - species 1 - id 29466
# Average adjusted fitness: 0.204
# Mean genetic distance 2.643, standard deviation 0.627
# Population of 500 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   59   270   7900.0    0.217     0
#      2   46    67   6800.0    0.213    23
#      3   24    94   6600.0    0.226    10
#      4    8    27   3100.0    0.181     1
#      5    1    42   1900.0    0.182     0
# Total extinctions: 0
# Generation time: 2.252 sec (2.127 average)
#
#  ****** Running generation 60 ******
#
# Population's average fitness: 1926.00000 stdev: 919.52379
# Best fitness: 6500.00000 - size: (4, 23) - species 3 - id 30052
# Average adjusted fitness: 0.252
# Mean genetic distance 2.622, standard deviation 0.613
# Population of 499 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   60   194   5700.0    0.258     1
#      2   47    96   5700.0    0.262    24
#      3   25   107   6500.0    0.302    11
#      4    9    28   2800.0    0.195     2
#      5    2    74   4800.0    0.245     0
# Total extinctions: 0
# Generation time: 3.608 sec (2.341 average)
#
#  ****** Running generation 61 ******
#
# Population's average fitness: 1838.27655 stdev: 817.78688
# Best fitness: 5400.00000 - size: (4, 24) - species 1 - id 30589
# Average adjusted fitness: 0.295
# Mean genetic distance 2.644, standard deviation 0.590
# Population of 500 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   61   193   5400.0    0.304     2
#      2   48   127   5100.0    0.305    25
#      3   26    85   4500.0    0.325    12
#      4   10    43   3500.0    0.272     3
#      5    3    52   4000.0    0.268     1
# Total extinctions: 0
# Generation time: 2.235 sec (2.410 average)
#
#  ****** Running generation 62 ******
#
# Population's average fitness: 1887.20000 stdev: 921.62691
# Best fitness: 6700.00000 - size: (4, 21) - species 1 - id 31296
# Average adjusted fitness: 0.272
# Mean genetic distance 2.636, standard deviation 0.611
# Population of 501 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   62   188   6700.0    0.301     3
#      2   49   121   5900.0    0.272    26
#      3   27    83   5500.0    0.283    13
#      4   11    38   4200.0    0.217     4
#      5    4    71   4600.0    0.286     2
# Total extinctions: 0
# Generation time: 2.390 sec (2.398 average)
#
#  ****** Running generation 63 ******
#
# Population's average fitness: 1863.47305 stdev: 826.07404
# Best fitness: 5100.00000 - size: (4, 22) - species 1 - id 31766
# Average adjusted fitness: 0.341
# Mean genetic distance 2.579, standard deviation 0.569
# Population of 501 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   63   168   5100.0    0.327     4
#      2   50    98   4500.0    0.351    27
#      3   28    86   4000.0    0.357    14
#      4   12    56   4300.0    0.340     5
#      5    5    93   5000.0    0.332     0
# Total extinctions: 0
# Generation time: 3.293 sec (2.505 average)
#
#  ****** Running generation 64 ******
#
# Population's average fitness: 1915.56886 stdev: 879.25590
# Best fitness: 6500.00000 - size: (4, 29) - species 5 - id 32145
#
# Species 2 with 98 members is stagnated: removing it
#
# Species 3 with 86 members is stagnated: removing it
# Average adjusted fitness: 0.274
# Mean genetic distance 2.465, standard deviation 0.498
# Population of 499 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   64   220   5000.0    0.271     5
#      4   13   123   4900.0    0.280     6
#      5    6   156   6500.0    0.271     0
# Total extinctions: 0
# Generation time: 2.422 sec (2.584 average)
#
#  ****** Running generation 65 ******
#
# Population's average fitness: 1918.43687 stdev: 920.34495
# Best fitness: 8100.00000 - size: (4, 29) - species 1 - id 32713
# Average adjusted fitness: 0.226
# Mean genetic distance 2.488, standard deviation 0.523
# Population of 499 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   65   229   8100.0    0.237     0
#      4   14   113   7900.0    0.224     0
#      5    7   120   4700.0    0.217     1
#      6    0    18       --       --     0
#      7    0    19       --       --     0
# Total extinctions: 0
# Generation time: 1.712 sec (2.596 average)
#
#  ****** Running generation 66 ******
#
# Population's average fitness: 1905.21042 stdev: 885.58536
# Best fitness: 7200.00000 - size: (4, 21) - species 1 - id 33046
# Average adjusted fitness: 0.243
# Mean genetic distance 2.643, standard deviation 0.546
# Population of 500 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   66   129   7200.0    0.243     1
#      4   15    59   4000.0    0.230     1
#      5    8   144   5300.0    0.257     2
#      6    1    54   3200.0    0.225     0
#      7    1   114   5100.0    0.260     0
# Total extinctions: 0
# Generation time: 1.902 sec (2.462 average)
#
#  ****** Running generation 67 ******
#
# Population's average fitness: 1899.40000 stdev: 913.50952
# Best fitness: 6700.00000 - size: (4, 22) - species 4 - id 33385
# Average adjusted fitness: 0.280
# Mean genetic distance 2.604, standard deviation 0.484
# Population of 499 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   67    66   5900.0    0.307     2
#      4   16    67   6700.0    0.282     2
#      5    9   163   5600.0    0.281     3
#      6    2    59   5600.0    0.253     0
#      7    2   144   5900.0    0.276     0
# Total extinctions: 0
# Generation time: 1.772 sec (2.383 average)
#
#  ****** Running generation 68 ******
#
# Population's average fitness: 2018.63727 stdev: 983.85430
# Best fitness: 7300.00000 - size: (4, 22) - species 1 - id 34032
# Average adjusted fitness: 0.273
# Mean genetic distance 2.495, standard deviation 0.452
# Population of 500 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   68   165   7300.0    0.296     3
#      4   17    89   4900.0    0.236     3
#      5   10    75   5700.0    0.280     4
#      6    3    62   4200.0    0.264     1
#      7    3   109   5500.0    0.288     1
# Total extinctions: 0
# Generation time: 2.200 sec (2.379 average)
#
#  ****** Running generation 69 ******
#
# Population's average fitness: 1977.40000 stdev: 974.24291
# Best fitness: 7900.00000 - size: (4, 22) - species 1 - id 34032
# Average adjusted fitness: 0.222
# Mean genetic distance 2.421, standard deviation 0.424
# Population of 501 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   69   158   7900.0    0.213     4
#      4   18    94   4800.0    0.201     4
#      5   11    95   5500.0    0.227     5
#      6    4    63   6300.0    0.234     0
#      7    4    91   5000.0    0.237     2
# Total extinctions: 0
# Generation time: 3.617 sec (2.515 average)
#
#  ****** Running generation 70 ******
#
# Population's average fitness: 2035.32934 stdev: 979.86177
# Best fitness: 7700.00000 - size: (5, 25) - species 7 - id 34982
# Average adjusted fitness: 0.226
# Mean genetic distance 2.451, standard deviation 0.420
# Population of 500 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   70   134   6100.0    0.209     5
#      4   19    95   6100.0    0.232     5
#      5   12   113   4700.0    0.239     6
#      6    5    65   4100.0    0.225     1
#      7    5    93   7700.0    0.226     0
# Total extinctions: 0
# Generation time: 1.987 sec (2.353 average)
#
#  ****** Running generation 71 ******
#
# Population's average fitness: 2066.60000 stdev: 1037.77861
# Best fitness: 6900.00000 - size: (6, 21) - species 1 - id 35469
# Average adjusted fitness: 0.281
# Mean genetic distance 2.434, standard deviation 0.406
# Population of 500 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   71   182   6900.0    0.256     6
#      4   20    68   6000.0    0.309     6
#      5   13   110   6300.0    0.280     7
#      6    6    70   5200.0    0.287     2
#      7    6    70   6300.0    0.273     1
# Total extinctions: 0
# Generation time: 1.649 sec (2.295 average)
#
#  ****** Running generation 72 ******
#
# Population's average fitness: 2091.60000 stdev: 981.83982
# Best fitness: 6200.00000 - size: (5, 25) - species 1 - id 36200
# Average adjusted fitness: 0.302
# Mean genetic distance 2.456, standard deviation 0.437
# Population of 500 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   72   133   6200.0    0.312     7
#      4   21    94   4400.0    0.302     7
#      5   14    50   5800.0    0.297     8
#      6    7    51   5800.0    0.316     3
#      7    7   153   3600.0    0.282     2
#      8    0    19       --       --     0
# Total extinctions: 0
# Generation time: 1.446 sec (2.200 average)
#
#  ****** Running generation 73 ******
#
# Population's average fitness: 2157.00000 stdev: 1049.80522
# Best fitness: 8600.00000 - size: (4, 19) - species 1 - id 36723
# Average adjusted fitness: 0.222
# Mean genetic distance 2.474, standard deviation 0.414
# Population of 499 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   73   126   8600.0    0.223     0
#      4   22    61   5800.0    0.226     8
#      5   15    51   5100.0    0.206     9
#      6    8    98   6300.0    0.233     4
#      7    8    90   6800.0    0.226     3
#      8    1    73   4100.0    0.218     0
# Total extinctions: 0
# Generation time: 1.540 sec (2.025 average)
#
#  ****** Running generation 74 ******
#
# Population's average fitness: 2182.16433 stdev: 1125.60940
# Best fitness: 10000.00000 - size: (6, 22) - species 1 - id 36922
#
# Best individual in generation 74 meets fitness threshold - complexity: (6, 22)
# [0, 0, 0, 0]
# [0, 0, 0, 2]
# [0, 0, 0, 0]
# [0, 0, 0, 2]
# Playing with winner
# ===============
# [0, 0, 4, 0]
# [2, 0, 0, 0]
# [0, 0, 0, 0]
# [2, 0, 0, 0]
# ===============
# ===============
# [0, 0, 0, 4]
# [0, 0, 0, 2]
# [0, 0, 0, 2]
# [0, 0, 0, 2]
# ===============
# ===============
# [4, 0, 2, 0]
# [2, 0, 0, 0]
# [2, 0, 0, 0]
# [2, 0, 0, 0]
# ===============
# ===============
# [4, 0, 2, 0]
# [4, 0, 0, 2]
# [2, 0, 0, 0]
# [0, 0, 0, 0]
# ===============
# ===============
# [8, 0, 2, 2]
# [2, 0, 0, 0]
# [0, 4, 0, 0]
# [0, 0, 0, 0]
# ===============
# ===============
# [8, 4, 2, 2]
# [2, 0, 0, 0]
# [0, 0, 0, 0]
# [2, 0, 0, 0]
# ===============
# ===============
# [8, 4, 2, 2]
# [4, 0, 0, 0]
# [0, 0, 0, 0]
# [2, 0, 0, 0]
# ===============
# ===============
# [8, 4, 2, 2]
# [4, 0, 0, 0]
# [2, 0, 0, 4]
# [0, 0, 0, 0]
# ===============
# ===============
# [8, 4, 4, 0]
# [4, 0, 0, 0]
# [2, 4, 4, 0]
# [0, 0, 0, 0]
# ===============
# ===============
# [8, 8, 8, 0]
# [4, 0, 0, 0]
# [2, 0, 0, 0]
# [2, 0, 0, 0]
# ===============
# ===============
# [8, 8, 8, 0]
# [4, 0, 0, 0]
# [4, 0, 0, 0]
# [0, 4, 0, 0]
# ===============
# ===============
# [8, 8, 8, 0]
# [8, 4, 0, 0]
# [0, 0, 4, 0]
# [0, 0, 0, 0]
# ===============
# ===============
# [0, 0, 8, 16]
# [0, 0, 8, 4]
# [0, 0, 4, 4]
# [0, 0, 0, 0]
# ===============
# ===============
# [8, 16, 2, 0]
# [8, 4, 0, 0]
# [8, 0, 0, 0]
# [0, 0, 0, 0]
# ===============
# ===============
# [0, 8, 16, 2]
# [0, 0, 8, 4]
# [0, 0, 0, 8]
# [0, 4, 0, 0]
# ===============
# ===============
# [8, 16, 2, 0]
# [8, 4, 0, 0]
# [8, 0, 4, 0]
# [4, 0, 0, 0]
# ===============
# ===============
# [0, 8, 16, 2]
# [0, 0, 8, 4]
# [0, 0, 8, 4]
# [0, 4, 0, 4]
# ===============
# ===============
# [8, 16, 2, 0]
# [8, 4, 0, 0]
# [8, 4, 0, 4]
# [8, 0, 0, 0]
# ===============
# ===============
# [8, 16, 2, 0]
# [8, 4, 0, 0]
# [8, 8, 4, 0]
# [8, 0, 0, 0]
# ===============
# ===============
# [16, 16, 2, 0]
# [16, 4, 4, 0]
# [0, 8, 0, 0]
# [2, 0, 0, 0]
# ===============
# ===============
# [32, 16, 2, 4]
# [2, 4, 4, 0]
# [0, 8, 0, 0]
# [0, 0, 0, 0]
# ===============
# ===============
# [32, 16, 2, 4]
# [2, 4, 4, 0]
# [0, 8, 2, 0]
# [0, 0, 0, 0]
# ===============
# ===============
# [32, 16, 2, 4]
# [2, 4, 4, 0]
# [0, 8, 2, 2]
# [0, 0, 0, 0]
# ===============
# ===============
# [32, 16, 2, 4]
# [2, 8, 0, 0]
# [8, 4, 0, 0]
# [0, 0, 0, 2]
# ===============
# ===============
# [32, 16, 2, 4]
# [2, 8, 0, 2]
# [8, 4, 0, 0]
# [2, 0, 0, 0]
# ===============
# ===============
# [32, 16, 2, 4]
# [2, 8, 0, 2]
# [8, 4, 0, 0]
# [2, 0, 0, 2]
# ===============
# ===============
# [32, 16, 2, 4]
# [2, 8, 0, 4]
# [8, 4, 0, 0]
# [2, 4, 0, 0]
# ===============
# ===============
# [32, 16, 2, 8]
# [2, 8, 0, 0]
# [8, 8, 2, 0]
# [2, 0, 0, 0]
# ===============
# ===============
# [32, 16, 4, 8]
# [2, 16, 0, 0]
# [8, 4, 0, 0]
# [2, 0, 0, 0]
# ===============
# ===============
# [32, 32, 4, 8]
# [2, 4, 0, 0]
# [8, 2, 0, 0]
# [2, 0, 0, 0]
# ===============
# ===============
# [32, 32, 4, 8]
# [2, 4, 0, 0]
# [8, 2, 0, 0]
# [2, 0, 0, 2]
# ===============
# ===============
# [32, 32, 4, 8]
# [2, 4, 0, 2]
# [8, 2, 2, 0]
# [2, 0, 0, 0]
# ===============
# ===============
# [32, 32, 4, 8]
# [2, 4, 2, 2]
# [8, 2, 0, 0]
# [2, 0, 0, 4]
# ===============
# ===============
# [32, 32, 4, 8]
# [2, 4, 2, 2]
# [8, 2, 0, 4]
# [2, 0, 0, 4]
# ===============
# ===============
# [64, 4, 8, 0]
# [4, 2, 4, 0]
# [8, 2, 4, 0]
# [2, 4, 0, 2]
# ===============
# ===============
# [64, 4, 8, 2]
# [4, 4, 8, 0]
# [8, 4, 0, 0]
# [2, 2, 0, 0]
# ===============
# ===============
# [64, 8, 16, 2]
# [4, 4, 0, 0]
# [8, 2, 4, 0]
# [2, 0, 0, 0]
# ===============
# ===============
# [64, 8, 16, 2]
# [4, 4, 4, 4]
# [8, 2, 0, 0]
# [2, 0, 0, 0]
# ===============
# ===============
# [64, 8, 16, 2]
# [4, 4, 4, 4]
# [8, 2, 0, 0]
# [2, 0, 2, 0]
# ===============
# ===============
# [64, 8, 16, 2]
# [4, 4, 4, 4]
# [8, 2, 2, 0]
# [2, 0, 0, 4]
# ===============
# ===============
# [64, 8, 16, 2]
# [4, 4, 4, 8]
# [8, 2, 2, 4]
# [2, 0, 0, 0]
# ===============
# ===============
# [64, 8, 16, 2]
# [8, 4, 8, 0]
# [8, 4, 4, 0]
# [2, 0, 2, 0]
# ===============
# ===============
# [64, 8, 16, 2]
# [16, 8, 8, 2]
# [2, 0, 4, 0]
# [0, 0, 2, 0]
# ===============
# ===============
# [64, 8, 16, 2]
# [16, 16, 2, 0]
# [2, 4, 0, 2]
# [2, 0, 0, 0]
# ===============
# ===============
# [64, 8, 16, 2]
# [32, 2, 0, 0]
# [8, 0, 2, 0]
# [2, 0, 0, 0]
# ===============
# ===============
# [64, 8, 16, 2]
# [32, 2, 2, 0]
# [8, 0, 0, 0]
# [2, 0, 0, 2]
# ===============
# ===============
# [64, 8, 16, 4]
# [32, 2, 2, 0]
# [8, 2, 0, 0]
# [2, 0, 0, 0]
# ===============
# ===============
# [64, 8, 16, 4]
# [32, 4, 2, 4]
# [8, 0, 0, 0]
# [2, 0, 0, 0]
# ===============
# ===============
# [64, 8, 16, 8]
# [32, 4, 2, 0]
# [8, 0, 0, 0]
# [2, 4, 0, 0]
# ===============
# ===============
# [64, 8, 16, 8]
# [32, 8, 2, 0]
# [8, 2, 0, 0]
# [2, 0, 0, 0]
# ===============
# ===============
# [64, 16, 16, 8]
# [32, 2, 2, 0]
# [8, 0, 0, 0]
# [2, 0, 4, 0]
# ===============
# ===============
# [64, 16, 16, 8]
# [32, 2, 2, 0]
# [8, 0, 4, 4]
# [2, 0, 0, 0]
# ===============
# ===============
# [64, 32, 8, 0]
# [32, 4, 0, 0]
# [8, 8, 0, 0]
# [2, 0, 0, 2]
# ===============
# ===============
# [64, 32, 8, 2]
# [32, 4, 0, 0]
# [8, 8, 0, 0]
# [2, 0, 0, 2]
# ===============
# ===============
# [64, 32, 8, 4]
# [32, 4, 4, 0]
# [8, 8, 0, 0]
# [2, 0, 0, 0]
# ===============
# ===============
# [64, 32, 8, 4]
# [32, 4, 4, 0]
# [8, 8, 2, 0]
# [2, 0, 0, 0]
# ===============
# ===============
# [64, 32, 8, 4]
# [32, 4, 4, 0]
# [8, 8, 2, 0]
# [2, 0, 4, 0]
# ===============
# ===============
# [64, 32, 8, 4]
# [32, 4, 4, 0]
# [8, 8, 2, 0]
# [2, 4, 4, 0]
# ===============
# ===============
# [64, 32, 8, 4]
# [32, 4, 4, 0]
# [8, 8, 2, 4]
# [2, 4, 4, 0]
# ===============
# ===============
# [64, 32, 8, 4]
# [32, 8, 0, 0]
# [16, 2, 4, 2]
# [2, 8, 0, 0]
# ===============
# ===============
# [64, 32, 8, 4]
# [32, 8, 0, 0]
# [16, 2, 4, 2]
# [2, 8, 4, 0]
# ===============
# ===============
# [64, 32, 8, 4]
# [32, 8, 4, 0]
# [16, 2, 4, 2]
# [2, 8, 4, 0]
# ===============
# ===============
# [64, 32, 8, 4]
# [32, 8, 4, 0]
# [16, 2, 4, 2]
# [2, 8, 4, 2]
# ===============
# ===============
# [64, 32, 8, 4]
# [32, 8, 4, 2]
# [16, 2, 4, 2]
# [8, 8, 0, 0]
# ===============
# ===============
# [64, 32, 8, 4]
# [32, 8, 8, 4]
# [16, 2, 0, 0]
# [8, 8, 0, 4]
# ===============
# ===============
# [64, 32, 16, 8]
# [32, 8, 0, 4]
# [16, 2, 0, 4]
# [8, 8, 0, 0]
# ===============
# ===============
# [64, 32, 16, 8]
# [32, 8, 4, 0]
# [16, 2, 4, 0]
# [16, 4, 0, 0]
# ===============
# ===============
# [64, 32, 16, 8]
# [32, 8, 8, 0]
# [32, 2, 0, 0]
# [0, 4, 4, 0]
# ===============
# ===============
# [64, 32, 16, 8]
# [32, 16, 0, 0]
# [32, 2, 4, 0]
# [8, 0, 0, 0]
# ===============
# ===============
# [64, 32, 16, 8]
# [0, 0, 32, 16]
# [4, 32, 2, 4]
# [0, 0, 0, 8]
# ===============
# ===============
# [64, 32, 16, 8]
# [32, 16, 0, 0]
# [32, 2, 8, 0]
# [8, 0, 0, 2]
# ===============
# ===============
# [64, 32, 16, 8]
# [0, 0, 32, 16]
# [0, 32, 2, 8]
# [4, 0, 8, 2]
# ===============
# ===============
# [64, 32, 16, 8]
# [32, 16, 0, 4]
# [32, 2, 8, 0]
# [4, 8, 2, 0]
# ===============
# ===============
# [64, 32, 16, 8]
# [64, 16, 8, 4]
# [4, 2, 2, 0]
# [0, 8, 2, 0]
# ===============
# ===============
# [64, 32, 16, 8]
# [64, 16, 8, 4]
# [4, 4, 0, 0]
# [8, 2, 4, 0]
# ===============
# ===============
# [128, 32, 16, 8]
# [4, 16, 8, 4]
# [8, 4, 4, 4]
# [0, 2, 0, 0]
# ===============
# ===============
# [128, 32, 16, 8]
# [16, 16, 0, 0]
# [8, 8, 4, 0]
# [2, 0, 0, 4]
# ===============
# ===============
# [128, 32, 16, 8]
# [16, 16, 4, 4]
# [8, 8, 0, 0]
# [2, 0, 0, 2]
# ===============
# ===============
# [128, 32, 16, 8]
# [16, 16, 4, 4]
# [8, 8, 0, 2]
# [2, 4, 0, 0]
# ===============
# ===============
# [128, 32, 16, 8]
# [32, 8, 0, 0]
# [16, 2, 0, 4]
# [2, 4, 0, 0]
# ===============
# ===============
# [128, 32, 16, 8]
# [32, 8, 0, 0]
# [16, 2, 4, 0]
# [2, 4, 2, 0]
# ===============
# ===============
# [128, 32, 16, 8]
# [32, 8, 4, 0]
# [16, 2, 2, 2]
# [2, 4, 0, 0]
# ===============
# ===============
# [128, 32, 16, 8]
# [32, 8, 4, 0]
# [16, 4, 2, 0]
# [2, 4, 4, 0]
# ===============
# ===============
# [128, 32, 16, 8]
# [32, 8, 4, 0]
# [16, 8, 2, 2]
# [2, 0, 4, 0]
# ===============
# ===============
# [128, 32, 16, 8]
# [32, 8, 4, 0]
# [16, 8, 4, 0]
# [2, 4, 0, 4]
# ===============
# ===============
# [128, 32, 16, 8]
# [32, 16, 8, 4]
# [16, 4, 0, 0]
# [2, 0, 4, 0]
# ===============
# ===============
# [128, 32, 16, 8]
# [32, 16, 8, 4]
# [16, 4, 0, 0]
# [2, 4, 0, 2]
# ===============
# ===============
# [128, 32, 16, 8]
# [32, 16, 8, 4]
# [16, 8, 0, 2]
# [2, 4, 0, 0]
# ===============
# ===============
# [128, 32, 16, 8]
# [32, 16, 8, 4]
# [16, 8, 2, 0]
# [2, 4, 4, 0]
# ===============
# ===============
# [128, 32, 16, 8]
# [32, 16, 8, 4]
# [16, 8, 2, 4]
# [2, 8, 0, 0]
# ===============
# ===============
# [128, 32, 16, 8]
# [32, 16, 8, 4]
# [16, 8, 2, 4]
# [2, 8, 2, 0]
# ===============
# ===============
# [128, 32, 16, 8]
# [32, 16, 8, 4]
# [16, 8, 2, 4]
# [2, 8, 2, 2]
# ===============
# ===============
# [128, 32, 16, 8]
# [32, 16, 8, 4]
# [16, 8, 2, 4]
# [8, 2, 4, 4]
# ===============
# ===============
# [128, 32, 16, 8]
# [32, 16, 8, 4]
# [16, 8, 2, 4]
# [8, 2, 8, 2]
# ===============
# ===============
# [128, 32, 16, 8]
# [32, 16, 8, 4]
# [16, 8, 2, 4]
# [8, 2, 8, 2]
# ===============
# ===============
# [128, 32, 16, 8]
# [32, 16, 8, 4]
# [16, 8, 2, 4]
# [8, 2, 8, 2]
# ===============
# ===============
# [128, 32, 16, 8]
# [32, 16, 8, 4]
# [16, 8, 2, 4]
# [8, 2, 8, 2]
# ===============
# ===============
# [128, 32, 16, 8]
# [32, 16, 8, 4]
# [16, 8, 2, 4]
# [8, 2, 8, 2]
# ===============
# ===============
# [128, 32, 16, 8]
# [32, 16, 8, 4]
# [16, 8, 2, 4]
# [8, 2, 8, 2]
# ===============
# ===============
# [128, 32, 16, 8]
# [32, 16, 8, 4]
# [16, 8, 2, 4]
# [8, 2, 8, 2]
# ===============
# ===============
# [128, 32, 16, 8]
# [32, 16, 8, 4]
# [16, 8, 2, 4]
# [8, 2, 8, 2]
# ===============
# ===============
# [128, 32, 16, 8]
# [32, 16, 8, 4]
# [16, 8, 2, 4]
# [8, 2, 8, 2]
# ===============
# ===============
# [128, 32, 16, 8]
# [32, 16, 8, 4]
# [16, 8, 2, 4]
# [8, 2, 8, 2]
# ===============
# ===============
# [128, 32, 16, 8]
# [32, 16, 8, 4]
# [16, 8, 2, 4]
# [8, 2, 8, 2]
# ===============
# ===============
# [128, 32, 16, 8]
# [32, 16, 8, 4]
# [16, 8, 2, 4]
# [8, 2, 8, 2]
# ===============
# Stuck
# Score: 1052
# Highest Tile: 128
